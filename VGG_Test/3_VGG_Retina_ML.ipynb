# %% [markdown]
# ## 0. 학습 세팅

# %% [markdown]
# ### 1) 메모리 정리

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ### 2) 수정된 코드 자동 업데이트

# %%
# %load_ext autoreload
# %autoreload 2
import foolbox as fb

# %% [markdown]
# ## 1. Load library

# %%
import os
import time
import copy
"""
import json
import glob

import numpy as np
from PIL import Image

from torchmetrics.aggregation import MeanMetric
"""
import argparse
import easydict

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
"""
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.datasets as Datasets
"""
import torchvision.transforms as T

from torch.utils.tensorboard import SummaryWriter
"""
import torch.utils.data as data
"""
from torch.utils.data import Dataset, DataLoader, random_split
from torchmetrics.functional.classification import accuracy

from src.models import vgg11_config, vgg13_config, vgg16_config
from src.models import VGG, get_vgg_layers
from src.engines import train, evaluate, get_predictions
from src.engines import plot_most_correct_wrong, epoch_time, normalize_image
from src.utils import load_checkpoint, save_checkpoint, save_transform

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ## 2. Variable Declaration

# %%
# # Jupyter 외 환경
# parser = argparse.ArgumentParser()
# parser.add_argument("--title", type=str, default="baseline")
# parser.add_argument("--device", type=str, default="cuda")
# parser.add_argument("--root", type=str, default="data")
# parser.add_argument("--batch_size", type=int, default=64)
# parser.add_argument("--num_workers", type=int, default=2)
# parser.add_argument("--epochs", type=int, default=100)
# parser.add_argument("--lr", type=float, default=0.001)
# parser.add_argument("--logs", type=str, default='logs')
# parser.add_argument("--checkpoints", type=str, default='checkpoints')
# parser.add_argument("--resume", type=bool, default=False)
# args = parser.parse_args()

# Jupyter 환경
args = easydict.EasyDict({
        "title" : "Retina_ML_7.5r1e-5_Aug3_GAN1125",
        "device" : "cuda",
        "root" : "data",
        "use_data" : "Retina_Some_binary_GAN1125", # Retina_Some_binary # Retina_Some_binary_GAN284 # Retina_Some_binary_GAN852 # Retina_student
        "batch_size" : 32, # !!!
        "num_workers" : 2,
        "epochs" : 100, # !!!
        "lr" : 7.5e-5, # !!!
        "logs" : "logs",
        "checkpoints" : "checkpoints",
        "transform_dir" : "transform_infor",
        "resume" : False,
        "train_ratio" : 0.8,
        "val_ratio" : 0.2,
        "test_ratio" : 1.0,
        "output_dim" : 2
    })

# %% [markdown]
# ## 3. Image Data Preprocessing

# %% [markdown]
# ### 1) 이미지 변환

# %%
"""
# Load Dataset
class RetinaDataset(Dataset):
    # image dataset 전체 경로 저장 -> tranform
    def __init__(self, root, transform=None):
        super(RetinaDataset, self).__init__()
        self.make_dataset(root)
        self.transform = transform
    
    # image dataset 전체 경로 저장
    def make_dataset(self, root):
        # class(폴더명) 불러오기
        self.data = []
        categories = os.listdir(root)
        categories = sorted(categories)
        
        # class -> label 변환 + 각 class의 이미지 파일 전부 가져오기
        for label, category in enumerate(categories):
            images = glob.glob(f'{root}/{category}/*.png')
            for image in images:
                self.data.append((image, label))
    
    # data 개수
    def __len__(self):
        return len(self.data)
    
    # 경로에 있는, 지정한 idx의 이미지 읽기 -> RGB 변환 -> tranform -> image, label 반환
    def __getitem__(self, idx):
        image, label = self.data[idx]
        image = self.read_image(image)
        if self.transform is not None:
            image = self.transform(image)
        return image, label
    
    # 경로에 있는 image 읽기 -> RGB 변환
    def read_image(self, path):
        image = Image.open(path)
        return image.convert('RGB')
"""

# Build dataset
"""
# train, val, test dataset load + make loader
transform = T.Compose([
    T.ToTensor(),
    T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
]) # transform을 train과 test 따로따로 설정해줘야하나?

dataset_root = "data/Retina"
dataset = RetinaDataset(dataset_root, transform)
train_size = int(dataset_size * args.train_ratio)
val_size = int(dataset_size * args.val_ratio)
test_size = dataset_size - train_size - val_size # random_split에서 dataset_size = train_size + val_size + test_size가 되지 않으면 오류 발생

print("[dataset load complete]") # 확인용 코드

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=args.batch_size, num_workers=args.num_workers, shuffle=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=args.batch_size, num_workers=args.num_workers, shuffle=True, drop_last=True)
test_loader = DataLoader(test_dataset, batch_size=args.batch_size, num_workers=args.num_workers, shuffle=False, drop_last=False)

# 확인용 코드
print(f"Training Data Size : {len(train_dataset)}")
print(f"Validation Data Size : {len(val_dataset)}")
print(f"Testing Data Size : {len(test_dataset)}")

print(f"train_dataset 개수 : {len(train_dataset)}, " + f"train_loader 개수 : {len(train_loader)}") # train_data 개수, train_loader batch set 개수
print(f"val_dataset 개수 : {len(val_dataset)}, " + f"val_loader 개수 : {len(val_loader)}") # val_data 개수, val_loader batch set 개수
print(f"test_dataset 개수 : {len(test_dataset)}, " + f"test_loader 개수 : {len(test_loader)}") # test_data 개수, test_loader batch set 개수

# Build model
model = ConvNet()
model = model.to(args.device)
"""
# 이미지 변환
train_transforms = T.Compose([
    T.Resize((256, 256)), # 이미지 크기 재조절
    T.RandomOrder([
        # T.RandomRotation(5), # 이미지 회전(5도 이하)
        # T.RandomHorizontalFlip(0.5), # 이미지 좌우 대칭(50% 확률)
#         T.RandomRotation(180),
        T.RandomHorizontalFlip(),
        T.RandomVerticalFlip(),
        T.RandomAutocontrast(),
#         T.GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 5)),
#         T.RandomAffine(180, shear=20),
#         T.RandomPerspective(fill=[255,255,255]),
#         T.RandomGrayscale(p=0.5),
#         T.RandomResizedCrop((256, 256)),
    ]),
    T.ToTensor(),
    T.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
])

test_transforms = T.Compose([
    T.Resize((256, 256)), 
    T.ToTensor(),
    T.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
])

# transform 정보 저장
save_transform(args.transform_dir, train_transforms, test_transforms, args.title)

# %% [markdown]
# ### 2) 이미지 데이터셋 불러오기 + 이미지 변환

# %%
train_path = f'C:\\Users\\Bang\\JupyterProjects\\RetinaProject\\DeepLearningPytorchExample\\data\\{args.use_data}\\train' 
test_path = f'C:\\Users\\Bang\\JupyterProjects\\RetinaProject\\DeepLearningPytorchExample\\data\\{args.use_data}\\test'

train_dataset = torchvision.datasets.ImageFolder(
    train_path, 
    transform = train_transforms
)
test_dataset = torchvision.datasets.ImageFolder(
    test_path, 
    transform = test_transforms
)

print("len(train_dataset) : ", len(train_dataset))
print("len(test_dataset) : ", len(test_dataset))
# Out:
# len(train_dataset) :  6782
# len(test_dataset) :  1132

# %% [markdown]
# ### 3) 훈련, 검증 데이터 분할 + 검증 이미지 재변환

# %%
all_train_dataset_size = len(train_dataset)
train_dataset_size = int(all_train_dataset_size * args.train_ratio)
valid_dataset_size = all_train_dataset_size - train_dataset_size

splited_train_dataset, splited_valid_dataset = random_split(train_dataset, [train_dataset_size, valid_dataset_size]) # 훈련 데이터셋, 검증 데이터셋 크기 결정

# %%
splited_valid_dataset = copy.deepcopy(splited_valid_dataset)
splited_valid_dataset.dataset.transform = test_transforms

# %% [markdown]
# ### 4) 데이터 로드 to 메모리

# %%
train_loader = DataLoader(splited_train_dataset,
                            shuffle = True,
                            batch_size = args.batch_size, 
                            num_workers=args.num_workers
                        )
val_loader = DataLoader(splited_valid_dataset,
                            batch_size = args.batch_size,
                            num_workers=args.num_workers
                        )
test_loader = DataLoader(test_dataset,
                            batch_size = args.batch_size,
                            num_workers=args.num_workers
                        )

print(f"train_dataset 개수 : {len(splited_train_dataset)}, " + f"train_loader 개수 : {len(train_loader)}") # train_data 개수, train_loader batch set 개수
print(f"val_dataset 개수 : {len(splited_valid_dataset)}, " + f"val_loader 개수 : {len(val_loader)}") # val_data 개수, val_loader batch set 개수
print(f"test_dataset 개수 : {len(test_dataset)}, " + f"test_loader 개수 : {len(test_loader)}") # test_data 개수, test_loader batch set 개수
# Out:
# train_dataset 개수 : 5425, train_loader 개수 : 170
# val_dataset 개수 : 1357, val_loader 개수 : 43
# test_dataset 개수 : 1132, test_loader 개수 : 36

# %% [markdown]
# ## 4. Model Define

# %% [markdown]
# ### 1) 모델 정의

# %%
# Build model
vgg11_layers = get_vgg_layers(vgg11_config, batch_norm = True)
model = VGG(vgg11_layers, args.output_dim)
model = model.to(args.device)

# %% [markdown]
# ### 2) 옵티마이저 + 손실함수 + 스케쥴러 + 메트릭 함수 정의

# %%
# Build optimizer 
optimizer = optim.Adam(model.parameters(), lr=args.lr)

# Build scheduler
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, args.epochs * len(train_loader))

# Build loss function
loss_fn = nn.CrossEntropyLoss()

# Build metric function
"""
# 정확도 측정 함수
def calculate_accuracy(y_pred, y): # ???
    top_pred = y_pred.argmax(1, keepdim = True)
    # print("top_pred : ", top_pred)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    # print("correct : ", correct)
    acc = correct.float() / y.shape[0]
    # print("acc : ", acc)
    return acc
"""
metric_fn = accuracy

# %% [markdown]
# ### 3) logger 정의

# %%
# Build logger
train_logger = SummaryWriter(f'{args.logs}/train/{args.title}')
val_logger = SummaryWriter(f'{args.logs}/val/{args.title}')
test_logger = SummaryWriter(f'{args.logs}/test/{args.title}')

# %% [markdown]
# ## 5. Model Train

# %% [markdown]
# ### 1) Load model epoch

# %%
# Load model
start_epoch = 0
if args.resume:
    start_epoch = load_checkpoint(args.checkpoints, args.title, model, optimizer)

# %% [markdown]
# ### 2) Train model

# %%
best_valid_loss = float('inf')
for epoch in range(start_epoch, args.epochs):
    """
    # start timer
    start_time = time.time() # 확인용 코드
    """
    # 모델 학습 소요시간
    start_time = time.monotonic()

    # train one epoch + evaluate one epoch
    train_summary = train(train_loader, model, optimizer, scheduler, loss_fn, metric_fn, args.device)
    val_summary = evaluate(val_loader, model, loss_fn, metric_fn, args.device)

    # write log
    train_logger.add_scalar('Loss', train_summary['loss'], epoch + 1)
    train_logger.add_scalar('Accuracy', train_summary['metric'], epoch + 1)
    val_logger.add_scalar('Loss', val_summary['loss'], epoch + 1)
    val_logger.add_scalar('Accuracy', val_summary['metric'], epoch + 1)

    # 최적 loss인 model 저장
    if val_summary['loss'] < best_valid_loss:
        best_valid_loss = val_summary['loss']
        torch.save(model.state_dict(), f'C:\\Users\\Bang\\JupyterProjects\\RetinaProject\\DeepLearningPytorchExample\\best_valid_model\\{args.title}.pt')

    # save model
    save_checkpoint(args.checkpoints, args.title, model, optimizer, epoch + 1)

    # 모델 학습 소요시간
    end_time = time.monotonic()
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    # Print log
    """
    print((
        f'[Epoch {epoch+1}] '
        + f'{epoch + 1}epoch time {end_time - start_time:.02f}, '
        + f'Train Loss {train_summary["loss"]:.04f}, '
        + f'Train Accuracy {train_summary["metric"]:.04f}, '
        + f'Test Loss {val_summary["loss"]:.04f}, '
        + f'Test Accuracy {val_summary["metric"]:.04f}'
    ))
    """
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\t Train Loss: {train_summary["loss"]:.3f} | Train Acc: {train_summary["metric"]:.2f}%')
    print(f'\t Valid Loss: {val_summary["loss"]:.3f} | Valid Acc: {val_summary["metric"]:.2f}%')
    print(f'\t scheduled_lr : {scheduler.get_last_lr()[0]}')
# Out:
# Epoch: 01 | Epoch Time: 1m 3s
# 	 Train Loss: 0.740 | Train Acc: 0.57%
# 	 Valid Loss: 0.676 | Valid Acc: 0.61%
# 	 scheduled_lr : 7.498149601371482e-05
# Epoch: 02 | Epoch Time: 0m 58s
# 	 Train Loss: 0.604 | Train Acc: 0.63%
# 	 Valid Loss: 0.682 | Valid Acc: 0.56%
# 	 scheduled_lr : 7.492600231606004e-05
# Epoch: 03 | Epoch Time: 0m 59s
# 	 Train Loss: 0.590 | Train Acc: 0.66%
# 	 Valid Loss: 0.607 | Valid Acc: 0.58%
# 	 scheduled_lr : 7.483357367261543e-05
# Epoch: 04 | Epoch Time: 0m 58s
# 	 Train Loss: 0.589 | Train Acc: 0.65%
# 	 Valid Loss: 0.915 | Valid Acc: 0.55%
# 	 scheduled_lr : 7.470430129929282e-05
# Epoch: 05 | Epoch Time: 0m 59s
# 	 Train Loss: 0.582 | Train Acc: 0.66%
# 	 Valid Loss: 0.575 | Valid Acc: 0.67%
# 	 scheduled_lr : 7.453831277231751e-05
# Epoch: 06 | Epoch Time: 0m 59s
# 	 Train Loss: 0.261 | Train Acc: 0.89%
# 	 Valid Loss: 0.630 | Valid Acc: 0.73%
# 	 scheduled_lr : 6.642280976741799e-07
# Epoch: 95 | Epoch Time: 0m 59s
# 	 Train Loss: 0.264 | Train Acc: 0.89%
# 	 Valid Loss: 0.630 | Valid Acc: 0.73%
# 	 scheduled_lr : 4.616872276823396e-07
# Epoch: 96 | Epoch Time: 0m 59s
# 	 Train Loss: 0.264 | Train Acc: 0.89%
# 	 Valid Loss: 0.637 | Valid Acc: 0.73%
# 	 scheduled_lr : 2.956987007070852e-07
# Epoch: 97 | Epoch Time: 0m 59s
# 	 Train Loss: 0.261 | Train Acc: 0.89%
# 	 Valid Loss: 0.640 | Valid Acc: 0.73%
# 	 scheduled_lr : 1.6642632738450132e-07
# Epoch: 98 | Epoch Time: 0m 59s
# 	 Train Loss: 0.268 | Train Acc: 0.89%
# 	 Valid Loss: 0.643 | Valid Acc: 0.73%
# 	 scheduled_lr : 7.399768393981698e-08
# Epoch: 99 | Epoch Time: 0m 59s
# 	 Train Loss: 0.260 | Train Acc: 0.89%
# 	 Valid Loss: 0.632 | Valid Acc: 0.73%
# 	 scheduled_lr : 1.850398628506511e-08
# Epoch: 100 | Epoch Time: 0m 59s
# 	 Train Loss: 0.266 | Train Acc: 0.88%
# 	 Valid Loss: 0.630 | Valid Acc: 0.73%
# 	 scheduled_lr : 0.0

# %% [markdown]
# ## 6. Model Test

# %%
# 학습된 모델 불러오기
model.load_state_dict(torch.load(f'C:\\Users\\Bang\\JupyterProjects\\RetinaProject\\DeepLearningPytorchExample\\best_valid_model\\{args.title}.pt'))

# 모델 성능 측정
test_summary = evaluate(test_loader, model, loss_fn, metric_fn, args.device)

# write log
test_logger.add_scalar('Loss', test_summary['loss'], epoch + 1)
test_logger.add_scalar('Accuracy', test_summary['metric'], epoch + 1)

print(f'Test Loss: {test_summary["loss"]:.3f} | Test Acc: {test_summary["metric"]:.2f}%')
# Out:
# Test Loss: 0.517 | Test Acc: 0.75%

# %%
# 학습된 모델 불러오기
model.load_state_dict(torch.load(f'C:\\Users\\Bang\\JupyterProjects\\RetinaProject\\DeepLearningPytorchExample\\best_valid_model\\Retina_ML_lr1e-6.pt'))

# 모델 성능 측정
test_summary = evaluate(test_loader, model, loss_fn, metric_fn, args.device)

# write log
test_logger.add_scalar('Loss', test_summary['loss'], epoch + 1)
test_logger.add_scalar('Accuracy', test_summary['metric'], epoch + 1)

print(f'Test Loss: {test_summary["loss"]:.3f} | Test Acc: {test_summary["metric"]:.2f}%')
# Out:
# Test Loss: 0.664 | Test Acc: 0.60%

# %% [markdown]
# ## 7. Model Prediction Print

# %% [markdown]
# ### 1) 예측한 값 추출 + 맞춘 이미지 정보 추출 + 틀린 이미지 정보 추출

# %%
correct_examples, wrong_examples = get_predictions(test_loader, model, args.device)

# %%
for correct_example in correct_examples: # 확인용 코드
    print("correct_example : ", correct_example[2])
for wrong_example in wrong_examples: # 확인용 코드
    print("wrong_example : ", wrong_example[2])
# Out:
# correct_example :  tensor([0.0388, 0.9612])
# correct_example :  tensor([0.0469, 0.9531])
# correct_example :  tensor([0.0694, 0.9306])
# correct_example :  tensor([0.0761, 0.9239])
# correct_example :  tensor([0.0796, 0.9204])
# correct_example :  tensor([0.0839, 0.9161])
# correct_example :  tensor([0.0862, 0.9138])
# correct_example :  tensor([0.0871, 0.9129])
# correct_example :  tensor([0.9116, 0.0884])
# correct_example :  tensor([0.9100, 0.0900])
# correct_example :  tensor([0.8956, 0.1044])
# correct_example :  tensor([0.8943, 0.1057])
# correct_example :  tensor([0.8940, 0.1060])
# correct_example :  tensor([0.1076, 0.8924])
# correct_example :  tensor([0.8869, 0.1131])
# correct_example :  tensor([0.1136, 0.8864])
# correct_example :  tensor([0.1198, 0.8802])
# correct_example :  tensor([0.8762, 0.1238])
# correct_example :  tensor([0.1241, 0.8759])
# correct_example :  tensor([0.8741, 0.1259])
# correct_example :  tensor([0.1272, 0.8728])
# correct_example :  tensor([0.1278, 0.8722])
# correct_example :  tensor([0.1284, 0.8716])
# correct_example :  tensor([0.8700, 0.1300])
# correct_example :  tensor([0.8698, 0.1302])
# correct_example :  tensor([0.1316, 0.8684])
# correct_example :  tensor([0.1318, 0.8682])
# correct_example :  tensor([0.1345, 0.8655])
# correct_example :  tensor([0.1370, 0.8630])
# correct_example :  tensor([0.8608, 0.1392])
# correct_example :  tensor([0.8591, 0.1409])
# correct_example :  tensor([0.8584, 0.1416])
# correct_example :  tensor([0.1429, 0.8571])
# correct_example :  tensor([0.1497, 0.8503])
# correct_example :  tensor([0.1505, 0.8495])
# correct_example :  tensor([0.8494, 0.1506])
# correct_example :  tensor([0.8483, 0.1517])
# correct_example :  tensor([0.8454, 0.1546])
# correct_example :  tensor([0.1565, 0.8435])
# correct_example :  tensor([0.8429, 0.1571])
# correct_example :  tensor([0.8413, 0.1587])
# correct_example :  tensor([0.8404, 0.1596])
# correct_example :  tensor([0.8401, 0.1599])
# correct_example :  tensor([0.8398, 0.1602])
# correct_example :  tensor([0.1607, 0.8393])
# correct_example :  tensor([0.8389, 0.1611])
# correct_example :  tensor([0.8381, 0.1619])
# correct_example :  tensor([0.8357, 0.1643])
# correct_example :  tensor([0.1649, 0.8351])
# correct_example :  tensor([0.8341, 0.1659])
# correct_example :  tensor([0.1666, 0.8334])
# correct_example :  tensor([0.1668, 0.8332])
# correct_example :  tensor([0.8304, 0.1696])
# correct_example :  tensor([0.8303, 0.1697])
# correct_example :  tensor([0.8292, 0.1708])
# correct_example :  tensor([0.8286, 0.1714])
# correct_example :  tensor([0.8282, 0.1718])
# correct_example :  tensor([0.1727, 0.8273])
# correct_example :  tensor([0.1733, 0.8267])
# correct_example :  tensor([0.8260, 0.1740])
# correct_example :  tensor([0.8253, 0.1747])
# correct_example :  tensor([0.1780, 0.8220])
# correct_example :  tensor([0.1782, 0.8218])
# correct_example :  tensor([0.8209, 0.1791])
# correct_example :  tensor([0.1798, 0.8202])
# correct_example :  tensor([0.8181, 0.1819])
# correct_example :  tensor([0.1820, 0.8180])
# correct_example :  tensor([0.8176, 0.1824])
# correct_example :  tensor([0.8131, 0.1869])
# correct_example :  tensor([0.8129, 0.1871])
# correct_example :  tensor([0.8099, 0.1901])
# correct_example :  tensor([0.8097, 0.1903])
# correct_example :  tensor([0.8080, 0.1920])
# correct_example :  tensor([0.1937, 0.8063])
# correct_example :  tensor([0.8061, 0.1939])
# correct_example :  tensor([0.8052, 0.1948])
# correct_example :  tensor([0.8049, 0.1951])
# correct_example :  tensor([0.8042, 0.1958])
# correct_example :  tensor([0.8033, 0.1967])
# correct_example :  tensor([0.1976, 0.8024])
# correct_example :  tensor([0.1980, 0.8020])
# correct_example :  tensor([0.1986, 0.8014])
# correct_example :  tensor([0.1987, 0.8013])
# correct_example :  tensor([0.1990, 0.8010])
# correct_example :  tensor([0.8006, 0.1994])
# correct_example :  tensor([0.7994, 0.2006])
# correct_example :  tensor([0.7990, 0.2010])
# correct_example :  tensor([0.7987, 0.2013])
# correct_example :  tensor([0.7980, 0.2020])
# correct_example :  tensor([0.7976, 0.2024])
# correct_example :  tensor([0.7974, 0.2026])
# correct_example :  tensor([0.7961, 0.2039])
# correct_example :  tensor([0.7930, 0.2070])
# correct_example :  tensor([0.7928, 0.2072])
# correct_example :  tensor([0.7921, 0.2079])
# correct_example :  tensor([0.7920, 0.2080])
# correct_example :  tensor([0.7920, 0.2080])
# correct_example :  tensor([0.7919, 0.2081])
# correct_example :  tensor([0.7892, 0.2108])
# correct_example :  tensor([0.2127, 0.7873])
# correct_example :  tensor([0.2137, 0.7863])
# correct_example :  tensor([0.7858, 0.2142])
# correct_example :  tensor([0.7856, 0.2144])
# correct_example :  tensor([0.7856, 0.2144])
# correct_example :  tensor([0.2147, 0.7853])
# correct_example :  tensor([0.2167, 0.7833])
# correct_example :  tensor([0.2169, 0.7831])
# correct_example :  tensor([0.2178, 0.7822])
# correct_example :  tensor([0.2190, 0.7810])
# correct_example :  tensor([0.7800, 0.2200])
# correct_example :  tensor([0.2209, 0.7791])
# correct_example :  tensor([0.7786, 0.2214])
# correct_example :  tensor([0.7783, 0.2217])
# correct_example :  tensor([0.7781, 0.2219])
# correct_example :  tensor([0.2271, 0.7729])
# correct_example :  tensor([0.7728, 0.2272])
# correct_example :  tensor([0.7727, 0.2273])
# correct_example :  tensor([0.7726, 0.2274])
# correct_example :  tensor([0.2280, 0.7720])
# correct_example :  tensor([0.2295, 0.7705])
# correct_example :  tensor([0.7704, 0.2296])
# correct_example :  tensor([0.7704, 0.2296])
# correct_example :  tensor([0.7691, 0.2309])
# correct_example :  tensor([0.7688, 0.2312])
# correct_example :  tensor([0.2314, 0.7686])
# correct_example :  tensor([0.7678, 0.2322])
# correct_example :  tensor([0.2324, 0.7676])
# correct_example :  tensor([0.2329, 0.7671])
# correct_example :  tensor([0.7668, 0.2332])
# correct_example :  tensor([0.7661, 0.2339])
# correct_example :  tensor([0.7645, 0.2355])
# correct_example :  tensor([0.7642, 0.2358])
# correct_example :  tensor([0.7625, 0.2375])
# correct_example :  tensor([0.7617, 0.2383])
# correct_example :  tensor([0.2399, 0.7601])
# correct_example :  tensor([0.2411, 0.7589])
# correct_example :  tensor([0.7564, 0.2436])
# correct_example :  tensor([0.2438, 0.7562])
# correct_example :  tensor([0.2454, 0.7546])
# correct_example :  tensor([0.7543, 0.2457])
# correct_example :  tensor([0.7540, 0.2460])
# correct_example :  tensor([0.7540, 0.2460])
# correct_example :  tensor([0.7530, 0.2470])
# correct_example :  tensor([0.7528, 0.2472])
# correct_example :  tensor([0.7527, 0.2473])
# correct_example :  tensor([0.2497, 0.7503])
# correct_example :  tensor([0.2508, 0.7492])
# correct_example :  tensor([0.7489, 0.2511])
# correct_example :  tensor([0.2517, 0.7483])
# correct_example :  tensor([0.7480, 0.2520])
# correct_example :  tensor([0.2523, 0.7477])
# correct_example :  tensor([0.2534, 0.7466])
# correct_example :  tensor([0.7448, 0.2552])
# correct_example :  tensor([0.7447, 0.2553])
# correct_example :  tensor([0.7445, 0.2555])
# correct_example :  tensor([0.7421, 0.2579])
# correct_example :  tensor([0.2588, 0.7412])
# correct_example :  tensor([0.7408, 0.2592])
# correct_example :  tensor([0.7400, 0.2600])
# correct_example :  tensor([0.2603, 0.7397])
# correct_example :  tensor([0.2611, 0.7389])
# correct_example :  tensor([0.7385, 0.2615])
# correct_example :  tensor([0.7377, 0.2623])
# correct_example :  tensor([0.7365, 0.2635])
# correct_example :  tensor([0.7352, 0.2648])
# correct_example :  tensor([0.7350, 0.2650])
# correct_example :  tensor([0.7343, 0.2657])
# correct_example :  tensor([0.2658, 0.7342])
# correct_example :  tensor([0.7337, 0.2663])
# correct_example :  tensor([0.7337, 0.2663])
# correct_example :  tensor([0.2665, 0.7335])
# correct_example :  tensor([0.2668, 0.7332])
# correct_example :  tensor([0.2670, 0.7330])
# correct_example :  tensor([0.2673, 0.7327])
# correct_example :  tensor([0.7313, 0.2687])
# correct_example :  tensor([0.7311, 0.2689])
# correct_example :  tensor([0.7310, 0.2690])
# correct_example :  tensor([0.7310, 0.2690])
# correct_example :  tensor([0.7307, 0.2693])
# correct_example :  tensor([0.2694, 0.7306])
# correct_example :  tensor([0.7306, 0.2694])
# correct_example :  tensor([0.2696, 0.7304])
# correct_example :  tensor([0.7296, 0.2704])
# correct_example :  tensor([0.7294, 0.2706])
# correct_example :  tensor([0.2715, 0.7285])
# correct_example :  tensor([0.2719, 0.7281])
# correct_example :  tensor([0.2721, 0.7279])
# correct_example :  tensor([0.7265, 0.2735])
# correct_example :  tensor([0.7262, 0.2738])
# correct_example :  tensor([0.7260, 0.2740])
# correct_example :  tensor([0.7256, 0.2744])
# correct_example :  tensor([0.2744, 0.7256])
# correct_example :  tensor([0.2752, 0.7248])
# correct_example :  tensor([0.2757, 0.7243])
# correct_example :  tensor([0.7226, 0.2774])
# correct_example :  tensor([0.7223, 0.2777])
# correct_example :  tensor([0.7215, 0.2785])
# correct_example :  tensor([0.7212, 0.2788])
# correct_example :  tensor([0.7197, 0.2803])
# correct_example :  tensor([0.7196, 0.2804])
# correct_example :  tensor([0.2805, 0.7195])
# correct_example :  tensor([0.2806, 0.7194])
# correct_example :  tensor([0.7192, 0.2808])
# correct_example :  tensor([0.2809, 0.7191])
# correct_example :  tensor([0.2809, 0.7191])
# correct_example :  tensor([0.2810, 0.7190])
# correct_example :  tensor([0.2815, 0.7185])
# correct_example :  tensor([0.2818, 0.7182])
# correct_example :  tensor([0.7178, 0.2822])
# correct_example :  tensor([0.7174, 0.2826])
# correct_example :  tensor([0.2828, 0.7172])
# correct_example :  tensor([0.7166, 0.2834])
# correct_example :  tensor([0.2834, 0.7166])
# correct_example :  tensor([0.7165, 0.2835])
# correct_example :  tensor([0.7165, 0.2835])
# correct_example :  tensor([0.2858, 0.7142])
# correct_example :  tensor([0.7135, 0.2865])
# correct_example :  tensor([0.7130, 0.2870])
# correct_example :  tensor([0.7118, 0.2882])
# correct_example :  tensor([0.7114, 0.2886])
# correct_example :  tensor([0.2905, 0.7095])
# correct_example :  tensor([0.2910, 0.7090])
# correct_example :  tensor([0.7086, 0.2914])
# correct_example :  tensor([0.7076, 0.2924])
# correct_example :  tensor([0.7071, 0.2929])
# correct_example :  tensor([0.7069, 0.2931])
# correct_example :  tensor([0.2935, 0.7065])
# correct_example :  tensor([0.7055, 0.2945])
# correct_example :  tensor([0.2949, 0.7051])
# correct_example :  tensor([0.2951, 0.7049])
# correct_example :  tensor([0.7046, 0.2954])
# correct_example :  tensor([0.2961, 0.7039])
# correct_example :  tensor([0.7030, 0.2970])
# correct_example :  tensor([0.7030, 0.2970])
# correct_example :  tensor([0.2973, 0.7027])
# correct_example :  tensor([0.2974, 0.7026])
# correct_example :  tensor([0.7022, 0.2978])
# correct_example :  tensor([0.2985, 0.7015])
# correct_example :  tensor([0.2987, 0.7013])
# correct_example :  tensor([0.7009, 0.2991])
# correct_example :  tensor([0.7003, 0.2997])
# correct_example :  tensor([0.7002, 0.2998])
# correct_example :  tensor([0.7001, 0.2999])
# correct_example :  tensor([0.2999, 0.7001])
# correct_example :  tensor([0.3003, 0.6997])
# correct_example :  tensor([0.6997, 0.3003])
# correct_example :  tensor([0.3007, 0.6993])
# correct_example :  tensor([0.6989, 0.3011])
# correct_example :  tensor([0.3013, 0.6987])
# correct_example :  tensor([0.6975, 0.3025])
# correct_example :  tensor([0.3027, 0.6973])
# correct_example :  tensor([0.6973, 0.3027])
# correct_example :  tensor([0.3044, 0.6956])
# correct_example :  tensor([0.6956, 0.3044])
# correct_example :  tensor([0.3056, 0.6944])
# correct_example :  tensor([0.6940, 0.3060])
# correct_example :  tensor([0.6939, 0.3061])
# correct_example :  tensor([0.3067, 0.6933])
# correct_example :  tensor([0.3071, 0.6929])
# correct_example :  tensor([0.3090, 0.6910])
# correct_example :  tensor([0.3091, 0.6909])
# correct_example :  tensor([0.6904, 0.3096])
# correct_example :  tensor([0.6898, 0.3102])
# correct_example :  tensor([0.3104, 0.6896])
# correct_example :  tensor([0.6886, 0.3114])
# correct_example :  tensor([0.6882, 0.3118])
# correct_example :  tensor([0.6878, 0.3122])
# correct_example :  tensor([0.6872, 0.3128])
# correct_example :  tensor([0.6858, 0.3142])
# correct_example :  tensor([0.3146, 0.6854])
# correct_example :  tensor([0.3147, 0.6853])
# correct_example :  tensor([0.6848, 0.3152])
# correct_example :  tensor([0.3155, 0.6845])
# correct_example :  tensor([0.6844, 0.3156])
# correct_example :  tensor([0.6843, 0.3157])
# correct_example :  tensor([0.6833, 0.3167])
# correct_example :  tensor([0.3178, 0.6822])
# correct_example :  tensor([0.6821, 0.3179])
# correct_example :  tensor([0.3186, 0.6814])
# correct_example :  tensor([0.3186, 0.6814])
# correct_example :  tensor([0.6804, 0.3196])
# correct_example :  tensor([0.6802, 0.3198])
# correct_example :  tensor([0.6785, 0.3215])
# correct_example :  tensor([0.6770, 0.3230])
# correct_example :  tensor([0.6759, 0.3241])
# correct_example :  tensor([0.3256, 0.6744])
# correct_example :  tensor([0.6742, 0.3258])
# correct_example :  tensor([0.3264, 0.6736])
# correct_example :  tensor([0.3272, 0.6728])
# correct_example :  tensor([0.6728, 0.3272])
# correct_example :  tensor([0.6719, 0.3281])
# correct_example :  tensor([0.3285, 0.6715])
# correct_example :  tensor([0.3293, 0.6707])
# correct_example :  tensor([0.6695, 0.3305])
# correct_example :  tensor([0.6686, 0.3314])
# correct_example :  tensor([0.3322, 0.6678])
# correct_example :  tensor([0.6662, 0.3338])
# correct_example :  tensor([0.3349, 0.6651])
# correct_example :  tensor([0.6649, 0.3351])
# correct_example :  tensor([0.6648, 0.3352])
# correct_example :  tensor([0.3360, 0.6640])
# correct_example :  tensor([0.6638, 0.3362])
# correct_example :  tensor([0.6635, 0.3365])
# correct_example :  tensor([0.3373, 0.6627])
# correct_example :  tensor([0.3379, 0.6621])
# correct_example :  tensor([0.6620, 0.3380])
# correct_example :  tensor([0.3386, 0.6614])
# correct_example :  tensor([0.3391, 0.6609])
# correct_example :  tensor([0.6607, 0.3393])
# correct_example :  tensor([0.6607, 0.3393])
# correct_example :  tensor([0.3394, 0.6606])
# correct_example :  tensor([0.6603, 0.3397])
# correct_example :  tensor([0.3403, 0.6597])
# correct_example :  tensor([0.3404, 0.6596])
# correct_example :  tensor([0.6592, 0.3408])
# correct_example :  tensor([0.6591, 0.3409])
# correct_example :  tensor([0.3413, 0.6587])
# correct_example :  tensor([0.6586, 0.3414])
# correct_example :  tensor([0.3418, 0.6582])
# correct_example :  tensor([0.3420, 0.6580])
# correct_example :  tensor([0.6575, 0.3425])
# correct_example :  tensor([0.6563, 0.3437])
# correct_example :  tensor([0.6562, 0.3438])
# correct_example :  tensor([0.6559, 0.3441])
# correct_example :  tensor([0.3441, 0.6559])
# correct_example :  tensor([0.3445, 0.6555])
# correct_example :  tensor([0.6550, 0.3450])
# correct_example :  tensor([0.3456, 0.6544])
# correct_example :  tensor([0.6541, 0.3459])
# correct_example :  tensor([0.6537, 0.3463])
# correct_example :  tensor([0.3479, 0.6521])
# correct_example :  tensor([0.3480, 0.6520])
# correct_example :  tensor([0.3483, 0.6517])
# correct_example :  tensor([0.6517, 0.3483])
# correct_example :  tensor([0.6495, 0.3505])
# correct_example :  tensor([0.6482, 0.3518])
# correct_example :  tensor([0.3523, 0.6477])
# correct_example :  tensor([0.6477, 0.3523])
# correct_example :  tensor([0.3528, 0.6472])
# correct_example :  tensor([0.6465, 0.3535])
# correct_example :  tensor([0.6460, 0.3540])
# correct_example :  tensor([0.3546, 0.6454])
# correct_example :  tensor([0.6452, 0.3548])
# correct_example :  tensor([0.6448, 0.3552])
# correct_example :  tensor([0.6444, 0.3556])
# correct_example :  tensor([0.6441, 0.3559])
# correct_example :  tensor([0.6438, 0.3562])
# correct_example :  tensor([0.6431, 0.3569])
# correct_example :  tensor([0.3570, 0.6430])
# correct_example :  tensor([0.6422, 0.3578])
# correct_example :  tensor([0.3580, 0.6420])
# correct_example :  tensor([0.3587, 0.6413])
# correct_example :  tensor([0.3593, 0.6407])
# correct_example :  tensor([0.3596, 0.6404])
# correct_example :  tensor([0.6403, 0.3597])
# correct_example :  tensor([0.6403, 0.3597])
# correct_example :  tensor([0.6396, 0.3604])
# correct_example :  tensor([0.3604, 0.6396])
# correct_example :  tensor([0.6395, 0.3605])
# correct_example :  tensor([0.6395, 0.3605])
# correct_example :  tensor([0.3605, 0.6395])
# correct_example :  tensor([0.3608, 0.6392])
# correct_example :  tensor([0.3619, 0.6381])
# correct_example :  tensor([0.6377, 0.3623])
# correct_example :  tensor([0.6372, 0.3628])
# correct_example :  tensor([0.6370, 0.3630])
# correct_example :  tensor([0.6370, 0.3630])
# correct_example :  tensor([0.3633, 0.6367])
# correct_example :  tensor([0.3635, 0.6365])
# correct_example :  tensor([0.6362, 0.3638])
# correct_example :  tensor([0.6357, 0.3643])
# correct_example :  tensor([0.3644, 0.6356])
# correct_example :  tensor([0.3645, 0.6355])
# correct_example :  tensor([0.6337, 0.3663])
# correct_example :  tensor([0.3668, 0.6332])
# correct_example :  tensor([0.6319, 0.3681])
# correct_example :  tensor([0.3690, 0.6310])
# correct_example :  tensor([0.6307, 0.3693])
# correct_example :  tensor([0.3694, 0.6306])
# correct_example :  tensor([0.6305, 0.3695])
# correct_example :  tensor([0.3695, 0.6305])
# correct_example :  tensor([0.6297, 0.3703])
# correct_example :  tensor([0.3703, 0.6297])
# correct_example :  tensor([0.3713, 0.6287])
# correct_example :  tensor([0.6287, 0.3713])
# correct_example :  tensor([0.6282, 0.3718])
# correct_example :  tensor([0.6280, 0.3720])
# correct_example :  tensor([0.6279, 0.3721])
# correct_example :  tensor([0.6277, 0.3723])
# correct_example :  tensor([0.3729, 0.6271])
# correct_example :  tensor([0.3734, 0.6266])
# correct_example :  tensor([0.3743, 0.6257])
# correct_example :  tensor([0.3749, 0.6251])
# correct_example :  tensor([0.6241, 0.3759])
# correct_example :  tensor([0.3765, 0.6235])
# correct_example :  tensor([0.3771, 0.6229])
# correct_example :  tensor([0.3779, 0.6221])
# correct_example :  tensor([0.6220, 0.3780])
# correct_example :  tensor([0.3792, 0.6208])
# correct_example :  tensor([0.3797, 0.6203])
# correct_example :  tensor([0.6198, 0.3802])
# correct_example :  tensor([0.6189, 0.3811])
# correct_example :  tensor([0.3811, 0.6189])
# correct_example :  tensor([0.6188, 0.3812])
# correct_example :  tensor([0.3814, 0.6186])
# correct_example :  tensor([0.3816, 0.6184])
# correct_example :  tensor([0.6179, 0.3821])
# correct_example :  tensor([0.6177, 0.3823])
# correct_example :  tensor([0.6172, 0.3828])
# correct_example :  tensor([0.6166, 0.3834])
# correct_example :  tensor([0.6162, 0.3838])
# correct_example :  tensor([0.3841, 0.6159])
# correct_example :  tensor([0.6154, 0.3846])
# correct_example :  tensor([0.6153, 0.3847])
# correct_example :  tensor([0.3851, 0.6149])
# correct_example :  tensor([0.6137, 0.3863])
# correct_example :  tensor([0.6136, 0.3864])
# correct_example :  tensor([0.6130, 0.3870])
# correct_example :  tensor([0.6117, 0.3883])
# correct_example :  tensor([0.3885, 0.6115])
# correct_example :  tensor([0.6115, 0.3885])
# correct_example :  tensor([0.3886, 0.6114])
# correct_example :  tensor([0.6114, 0.3886])
# correct_example :  tensor([0.6114, 0.3886])
# correct_example :  tensor([0.3889, 0.6111])
# correct_example :  tensor([0.3899, 0.6101])
# correct_example :  tensor([0.3902, 0.6098])
# correct_example :  tensor([0.6095, 0.3905])
# correct_example :  tensor([0.6093, 0.3907])
# correct_example :  tensor([0.6087, 0.3913])
# correct_example :  tensor([0.6086, 0.3914])
# correct_example :  tensor([0.3914, 0.6086])
# correct_example :  tensor([0.6079, 0.3921])
# correct_example :  tensor([0.3921, 0.6079])
# correct_example :  tensor([0.6078, 0.3922])
# correct_example :  tensor([0.6077, 0.3923])
# correct_example :  tensor([0.3927, 0.6073])
# correct_example :  tensor([0.6058, 0.3942])
# correct_example :  tensor([0.3943, 0.6057])
# correct_example :  tensor([0.6056, 0.3944])
# correct_example :  tensor([0.3948, 0.6052])
# correct_example :  tensor([0.6051, 0.3949])
# correct_example :  tensor([0.3951, 0.6049])
# correct_example :  tensor([0.3958, 0.6042])
# correct_example :  tensor([0.6039, 0.3961])
# correct_example :  tensor([0.3966, 0.6034])
# correct_example :  tensor([0.3968, 0.6032])
# correct_example :  tensor([0.3972, 0.6028])
# correct_example :  tensor([0.6009, 0.3991])
# correct_example :  tensor([0.4001, 0.5999])
# correct_example :  tensor([0.4008, 0.5992])
# correct_example :  tensor([0.5987, 0.4013])
# correct_example :  tensor([0.5981, 0.4019])
# correct_example :  tensor([0.4022, 0.5978])
# correct_example :  tensor([0.5971, 0.4029])
# correct_example :  tensor([0.5966, 0.4034])
# correct_example :  tensor([0.5965, 0.4035])
# correct_example :  tensor([0.5962, 0.4038])
# correct_example :  tensor([0.5953, 0.4047])
# correct_example :  tensor([0.5951, 0.4049])
# correct_example :  tensor([0.4056, 0.5944])
# correct_example :  tensor([0.5938, 0.4062])
# correct_example :  tensor([0.4064, 0.5936])
# correct_example :  tensor([0.4066, 0.5934])
# correct_example :  tensor([0.5931, 0.4069])
# correct_example :  tensor([0.4073, 0.5927])
# correct_example :  tensor([0.5923, 0.4077])
# correct_example :  tensor([0.4078, 0.5922])
# correct_example :  tensor([0.4078, 0.5922])
# correct_example :  tensor([0.5917, 0.4083])
# correct_example :  tensor([0.5906, 0.4094])
# correct_example :  tensor([0.4102, 0.5898])
# correct_example :  tensor([0.5898, 0.4102])
# correct_example :  tensor([0.5889, 0.4111])
# correct_example :  tensor([0.4128, 0.5872])
# correct_example :  tensor([0.5868, 0.4132])
# correct_example :  tensor([0.4138, 0.5862])
# correct_example :  tensor([0.5861, 0.4139])
# correct_example :  tensor([0.4145, 0.5855])
# correct_example :  tensor([0.5850, 0.4150])
# correct_example :  tensor([0.4154, 0.5846])
# correct_example :  tensor([0.5837, 0.4163])
# correct_example :  tensor([0.4164, 0.5836])
# correct_example :  tensor([0.5833, 0.4167])
# correct_example :  tensor([0.4173, 0.5827])
# correct_example :  tensor([0.4176, 0.5824])
# correct_example :  tensor([0.4176, 0.5824])
# correct_example :  tensor([0.5822, 0.4178])
# correct_example :  tensor([0.5818, 0.4182])
# correct_example :  tensor([0.4190, 0.5810])
# correct_example :  tensor([0.4197, 0.5803])
# correct_example :  tensor([0.4199, 0.5801])
# correct_example :  tensor([0.5800, 0.4200])
# correct_example :  tensor([0.4201, 0.5799])
# correct_example :  tensor([0.4206, 0.5794])
# correct_example :  tensor([0.5788, 0.4212])
# correct_example :  tensor([0.4221, 0.5779])
# correct_example :  tensor([0.5766, 0.4234])
# correct_example :  tensor([0.4240, 0.5760])
# correct_example :  tensor([0.5759, 0.4241])
# correct_example :  tensor([0.4256, 0.5744])
# correct_example :  tensor([0.4270, 0.5730])
# correct_example :  tensor([0.5721, 0.4279])
# correct_example :  tensor([0.4281, 0.5719])
# correct_example :  tensor([0.5712, 0.4288])
# correct_example :  tensor([0.5700, 0.4300])
# correct_example :  tensor([0.4303, 0.5697])
# correct_example :  tensor([0.5696, 0.4304])
# correct_example :  tensor([0.4304, 0.5696])
# correct_example :  tensor([0.5694, 0.4306])
# correct_example :  tensor([0.4309, 0.5691])
# correct_example :  tensor([0.5687, 0.4313])
# correct_example :  tensor([0.5683, 0.4317])
# correct_example :  tensor([0.5682, 0.4318])
# correct_example :  tensor([0.5682, 0.4318])
# correct_example :  tensor([0.4321, 0.5679])
# correct_example :  tensor([0.4321, 0.5679])
# correct_example :  tensor([0.5678, 0.4322])
# correct_example :  tensor([0.4323, 0.5677])
# correct_example :  tensor([0.5669, 0.4331])
# correct_example :  tensor([0.4335, 0.5665])
# correct_example :  tensor([0.5664, 0.4336])
# correct_example :  tensor([0.5661, 0.4339])
# correct_example :  tensor([0.5660, 0.4340])
# correct_example :  tensor([0.4342, 0.5658])
# correct_example :  tensor([0.4346, 0.5654])
# correct_example :  tensor([0.4346, 0.5654])
# correct_example :  tensor([0.4346, 0.5654])
# correct_example :  tensor([0.5654, 0.4346])
# correct_example :  tensor([0.4349, 0.5651])
# correct_example :  tensor([0.4357, 0.5643])
# correct_example :  tensor([0.5638, 0.4362])
# correct_example :  tensor([0.5630, 0.4370])
# correct_example :  tensor([0.4378, 0.5622])
# correct_example :  tensor([0.4379, 0.5621])
# correct_example :  tensor([0.5613, 0.4387])
# correct_example :  tensor([0.4390, 0.5610])
# correct_example :  tensor([0.4397, 0.5603])
# correct_example :  tensor([0.5599, 0.4401])
# correct_example :  tensor([0.5598, 0.4402])
# correct_example :  tensor([0.5596, 0.4404])
# correct_example :  tensor([0.5583, 0.4417])
# correct_example :  tensor([0.5582, 0.4418])
# correct_example :  tensor([0.4423, 0.5577])
# correct_example :  tensor([0.4429, 0.5571])
# correct_example :  tensor([0.4435, 0.5565])
# correct_example :  tensor([0.5564, 0.4436])
# correct_example :  tensor([0.4437, 0.5563])
# correct_example :  tensor([0.5556, 0.4444])
# correct_example :  tensor([0.4445, 0.5555])
# correct_example :  tensor([0.5545, 0.4455])
# correct_example :  tensor([0.5539, 0.4461])
# correct_example :  tensor([0.4463, 0.5537])
# correct_example :  tensor([0.5535, 0.4465])
# correct_example :  tensor([0.4470, 0.5530])
# correct_example :  tensor([0.5523, 0.4477])
# correct_example :  tensor([0.5520, 0.4480])
# correct_example :  tensor([0.4490, 0.5510])
# correct_example :  tensor([0.5497, 0.4503])
# correct_example :  tensor([0.4511, 0.5489])
# correct_example :  tensor([0.4512, 0.5488])
# correct_example :  tensor([0.4515, 0.5485])
# correct_example :  tensor([0.4518, 0.5482])
# correct_example :  tensor([0.5481, 0.4519])
# correct_example :  tensor([0.4519, 0.5481])
# correct_example :  tensor([0.4526, 0.5474])
# correct_example :  tensor([0.4532, 0.5468])
# correct_example :  tensor([0.4532, 0.5468])
# correct_example :  tensor([0.4536, 0.5464])
# correct_example :  tensor([0.5464, 0.4536])
# correct_example :  tensor([0.4541, 0.5459])
# correct_example :  tensor([0.5453, 0.4547])
# correct_example :  tensor([0.5444, 0.4556])
# correct_example :  tensor([0.5441, 0.4559])
# correct_example :  tensor([0.4567, 0.5433])
# correct_example :  tensor([0.4569, 0.5431])
# correct_example :  tensor([0.4571, 0.5429])
# correct_example :  tensor([0.4575, 0.5425])
# correct_example :  tensor([0.5422, 0.4578])
# correct_example :  tensor([0.4581, 0.5419])
# correct_example :  tensor([0.4583, 0.5417])
# correct_example :  tensor([0.5415, 0.4585])
# correct_example :  tensor([0.5414, 0.4586])
# correct_example :  tensor([0.4594, 0.5406])
# correct_example :  tensor([0.5403, 0.4597])
# correct_example :  tensor([0.4600, 0.5400])
# correct_example :  tensor([0.4601, 0.5399])
# correct_example :  tensor([0.5396, 0.4604])
# correct_example :  tensor([0.5395, 0.4605])
# correct_example :  tensor([0.4610, 0.5390])
# correct_example :  tensor([0.4619, 0.5381])
# correct_example :  tensor([0.5375, 0.4625])
# correct_example :  tensor([0.5373, 0.4627])
# correct_example :  tensor([0.4630, 0.5370])
# correct_example :  tensor([0.4638, 0.5362])
# correct_example :  tensor([0.4642, 0.5358])
# correct_example :  tensor([0.5357, 0.4643])
# correct_example :  tensor([0.4647, 0.5353])
# correct_example :  tensor([0.5352, 0.4648])
# correct_example :  tensor([0.4652, 0.5348])
# correct_example :  tensor([0.4658, 0.5342])
# correct_example :  tensor([0.4664, 0.5336])
# correct_example :  tensor([0.4669, 0.5331])
# correct_example :  tensor([0.5316, 0.4684])
# correct_example :  tensor([0.5315, 0.4685])
# correct_example :  tensor([0.4688, 0.5312])
# correct_example :  tensor([0.4697, 0.5303])
# correct_example :  tensor([0.5301, 0.4699])
# correct_example :  tensor([0.5300, 0.4700])
# correct_example :  tensor([0.5296, 0.4704])
# correct_example :  tensor([0.5293, 0.4707])
# correct_example :  tensor([0.4710, 0.5290])
# correct_example :  tensor([0.5289, 0.4711])
# correct_example :  tensor([0.5289, 0.4711])
# correct_example :  tensor([0.4715, 0.5285])
# correct_example :  tensor([0.5282, 0.4718])
# correct_example :  tensor([0.5271, 0.4729])
# correct_example :  tensor([0.5270, 0.4730])
# correct_example :  tensor([0.5265, 0.4735])
# correct_example :  tensor([0.5260, 0.4740])
# correct_example :  tensor([0.5258, 0.4742])
# correct_example :  tensor([0.4742, 0.5258])
# correct_example :  tensor([0.5257, 0.4743])
# correct_example :  tensor([0.4748, 0.5252])
# correct_example :  tensor([0.4753, 0.5247])
# correct_example :  tensor([0.5235, 0.4765])
# correct_example :  tensor([0.5233, 0.4767])
# correct_example :  tensor([0.4774, 0.5226])
# correct_example :  tensor([0.4778, 0.5222])
# correct_example :  tensor([0.4795, 0.5205])
# correct_example :  tensor([0.4798, 0.5202])
# correct_example :  tensor([0.5200, 0.4800])
# correct_example :  tensor([0.5188, 0.4812])
# correct_example :  tensor([0.4812, 0.5188])
# correct_example :  tensor([0.4813, 0.5187])
# correct_example :  tensor([0.5185, 0.4815])
# correct_example :  tensor([0.4826, 0.5174])
# correct_example :  tensor([0.5162, 0.4838])
# correct_example :  tensor([0.4841, 0.5159])
# correct_example :  tensor([0.4842, 0.5158])
# correct_example :  tensor([0.5143, 0.4857])
# correct_example :  tensor([0.5135, 0.4865])
# correct_example :  tensor([0.4869, 0.5131])
# correct_example :  tensor([0.4875, 0.5125])
# correct_example :  tensor([0.5124, 0.4876])
# correct_example :  tensor([0.4878, 0.5122])
# correct_example :  tensor([0.4881, 0.5119])
# correct_example :  tensor([0.5116, 0.4884])
# correct_example :  tensor([0.5111, 0.4889])
# correct_example :  tensor([0.4890, 0.5110])
# correct_example :  tensor([0.4894, 0.5106])
# correct_example :  tensor([0.5105, 0.4895])
# correct_example :  tensor([0.4896, 0.5104])
# correct_example :  tensor([0.5103, 0.4897])
# correct_example :  tensor([0.4897, 0.5103])
# correct_example :  tensor([0.5103, 0.4897])
# correct_example :  tensor([0.4900, 0.5100])
# correct_example :  tensor([0.4902, 0.5098])
# correct_example :  tensor([0.5096, 0.4904])
# correct_example :  tensor([0.4904, 0.5096])
# correct_example :  tensor([0.5093, 0.4907])
# correct_example :  tensor([0.5089, 0.4911])
# correct_example :  tensor([0.4918, 0.5082])
# correct_example :  tensor([0.4918, 0.5082])
# correct_example :  tensor([0.4920, 0.5080])
# correct_example :  tensor([0.4924, 0.5076])
# correct_example :  tensor([0.4927, 0.5073])
# correct_example :  tensor([0.5072, 0.4928])
# correct_example :  tensor([0.4932, 0.5068])
# correct_example :  tensor([0.5049, 0.4951])
# correct_example :  tensor([0.4951, 0.5049])
# correct_example :  tensor([0.5040, 0.4960])
# correct_example :  tensor([0.5038, 0.4962])
# correct_example :  tensor([0.5035, 0.4965])
# correct_example :  tensor([0.4971, 0.5029])
# correct_example :  tensor([0.5029, 0.4971])
# correct_example :  tensor([0.5027, 0.4973])
# correct_example :  tensor([0.4976, 0.5024])
# correct_example :  tensor([0.4981, 0.5019])
# correct_example :  tensor([0.5019, 0.4981])
# correct_example :  tensor([0.4983, 0.5017])
# correct_example :  tensor([0.4998, 0.5002])
# wrong_example :  tensor([0.0399, 0.9601])
# wrong_example :  tensor([0.9338, 0.0662])
# wrong_example :  tensor([0.9217, 0.0783])
# wrong_example :  tensor([0.9073, 0.0927])
# wrong_example :  tensor([0.8697, 0.1303])
# wrong_example :  tensor([0.8622, 0.1378])
# wrong_example :  tensor([0.8584, 0.1416])
# wrong_example :  tensor([0.8558, 0.1442])
# wrong_example :  tensor([0.8543, 0.1457])
# wrong_example :  tensor([0.1651, 0.8349])
# wrong_example :  tensor([0.1671, 0.8329])
# wrong_example :  tensor([0.8306, 0.1694])
# wrong_example :  tensor([0.8303, 0.1697])
# wrong_example :  tensor([0.1725, 0.8275])
# wrong_example :  tensor([0.8166, 0.1834])
# wrong_example :  tensor([0.8160, 0.1840])
# wrong_example :  tensor([0.8159, 0.1841])
# wrong_example :  tensor([0.8149, 0.1851])
# wrong_example :  tensor([0.8127, 0.1873])
# wrong_example :  tensor([0.1883, 0.8117])
# wrong_example :  tensor([0.8038, 0.1962])
# wrong_example :  tensor([0.1965, 0.8035])
# wrong_example :  tensor([0.2001, 0.7999])
# wrong_example :  tensor([0.2017, 0.7983])
# wrong_example :  tensor([0.2020, 0.7980])
# wrong_example :  tensor([0.7958, 0.2042])
# wrong_example :  tensor([0.2057, 0.7943])
# wrong_example :  tensor([0.7913, 0.2087])
# wrong_example :  tensor([0.7898, 0.2102])
# wrong_example :  tensor([0.7883, 0.2117])
# wrong_example :  tensor([0.7879, 0.2121])
# wrong_example :  tensor([0.2143, 0.7857])
# wrong_example :  tensor([0.2167, 0.7833])
# wrong_example :  tensor([0.7792, 0.2208])
# wrong_example :  tensor([0.2237, 0.7763])
# wrong_example :  tensor([0.7732, 0.2268])
# wrong_example :  tensor([0.2293, 0.7707])
# wrong_example :  tensor([0.7701, 0.2299])
# wrong_example :  tensor([0.2321, 0.7679])
# wrong_example :  tensor([0.7665, 0.2335])
# wrong_example :  tensor([0.2362, 0.7638])
# wrong_example :  tensor([0.7621, 0.2379])
# wrong_example :  tensor([0.7572, 0.2428])
# wrong_example :  tensor([0.7571, 0.2429])
# wrong_example :  tensor([0.2477, 0.7523])
# wrong_example :  tensor([0.7517, 0.2483])
# wrong_example :  tensor([0.7466, 0.2534])
# wrong_example :  tensor([0.2539, 0.7461])
# wrong_example :  tensor([0.7458, 0.2542])
# wrong_example :  tensor([0.7422, 0.2578])
# wrong_example :  tensor([0.2580, 0.7420])
# wrong_example :  tensor([0.7391, 0.2609])
# wrong_example :  tensor([0.7357, 0.2643])
# wrong_example :  tensor([0.2678, 0.7322])
# wrong_example :  tensor([0.2689, 0.7311])
# wrong_example :  tensor([0.7291, 0.2709])
# wrong_example :  tensor([0.7290, 0.2710])
# wrong_example :  tensor([0.2712, 0.7288])
# wrong_example :  tensor([0.2732, 0.7268])
# wrong_example :  tensor([0.7257, 0.2743])
# wrong_example :  tensor([0.2749, 0.7251])
# wrong_example :  tensor([0.7248, 0.2752])
# wrong_example :  tensor([0.7241, 0.2759])
# wrong_example :  tensor([0.7218, 0.2782])
# wrong_example :  tensor([0.2823, 0.7177])
# wrong_example :  tensor([0.7174, 0.2826])
# wrong_example :  tensor([0.7172, 0.2828])
# wrong_example :  tensor([0.7170, 0.2830])
# wrong_example :  tensor([0.7162, 0.2838])
# wrong_example :  tensor([0.7137, 0.2863])
# wrong_example :  tensor([0.2876, 0.7124])
# wrong_example :  tensor([0.7121, 0.2879])
# wrong_example :  tensor([0.2900, 0.7100])
# wrong_example :  tensor([0.2931, 0.7069])
# wrong_example :  tensor([0.7069, 0.2931])
# wrong_example :  tensor([0.2949, 0.7051])
# wrong_example :  tensor([0.2954, 0.7046])
# wrong_example :  tensor([0.7024, 0.2976])
# wrong_example :  tensor([0.2997, 0.7003])
# wrong_example :  tensor([0.3002, 0.6998])
# wrong_example :  tensor([0.6996, 0.3004])
# wrong_example :  tensor([0.6989, 0.3011])
# wrong_example :  tensor([0.6982, 0.3018])
# wrong_example :  tensor([0.6981, 0.3019])
# wrong_example :  tensor([0.3020, 0.6980])
# wrong_example :  tensor([0.6972, 0.3028])
# wrong_example :  tensor([0.6967, 0.3033])
# wrong_example :  tensor([0.6965, 0.3035])
# wrong_example :  tensor([0.3044, 0.6956])
# wrong_example :  tensor([0.6946, 0.3054])
# wrong_example :  tensor([0.6930, 0.3070])
# wrong_example :  tensor([0.3100, 0.6900])
# wrong_example :  tensor([0.3104, 0.6896])
# wrong_example :  tensor([0.6889, 0.3111])
# wrong_example :  tensor([0.3117, 0.6883])
# wrong_example :  tensor([0.3120, 0.6880])
# wrong_example :  tensor([0.3122, 0.6878])
# wrong_example :  tensor([0.6859, 0.3141])
# wrong_example :  tensor([0.6857, 0.3143])
# wrong_example :  tensor([0.3148, 0.6852])
# wrong_example :  tensor([0.3155, 0.6845])
# wrong_example :  tensor([0.6830, 0.3170])
# wrong_example :  tensor([0.3178, 0.6822])
# wrong_example :  tensor([0.3194, 0.6806])
# wrong_example :  tensor([0.3210, 0.6790])
# wrong_example :  tensor([0.6790, 0.3210])
# wrong_example :  tensor([0.6782, 0.3218])
# wrong_example :  tensor([0.3224, 0.6776])
# wrong_example :  tensor([0.3234, 0.6766])
# wrong_example :  tensor([0.3237, 0.6763])
# wrong_example :  tensor([0.6760, 0.3240])
# wrong_example :  tensor([0.6756, 0.3244])
# wrong_example :  tensor([0.3250, 0.6750])
# wrong_example :  tensor([0.3255, 0.6745])
# wrong_example :  tensor([0.6743, 0.3257])
# wrong_example :  tensor([0.3272, 0.6728])
# wrong_example :  tensor([0.6693, 0.3307])
# wrong_example :  tensor([0.6693, 0.3307])
# wrong_example :  tensor([0.6692, 0.3308])
# wrong_example :  tensor([0.3309, 0.6691])
# wrong_example :  tensor([0.3309, 0.6691])
# wrong_example :  tensor([0.3310, 0.6690])
# wrong_example :  tensor([0.6679, 0.3321])
# wrong_example :  tensor([0.3332, 0.6668])
# wrong_example :  tensor([0.6664, 0.3336])
# wrong_example :  tensor([0.6661, 0.3339])
# wrong_example :  tensor([0.3367, 0.6633])
# wrong_example :  tensor([0.6628, 0.3372])
# wrong_example :  tensor([0.6610, 0.3390])
# wrong_example :  tensor([0.6603, 0.3397])
# wrong_example :  tensor([0.6601, 0.3399])
# wrong_example :  tensor([0.6559, 0.3441])
# wrong_example :  tensor([0.3442, 0.6558])
# wrong_example :  tensor([0.6552, 0.3448])
# wrong_example :  tensor([0.3454, 0.6546])
# wrong_example :  tensor([0.3455, 0.6545])
# wrong_example :  tensor([0.6542, 0.3458])
# wrong_example :  tensor([0.6536, 0.3464])
# wrong_example :  tensor([0.6528, 0.3472])
# wrong_example :  tensor([0.3473, 0.6527])
# wrong_example :  tensor([0.6527, 0.3473])
# wrong_example :  tensor([0.6523, 0.3477])
# wrong_example :  tensor([0.6507, 0.3493])
# wrong_example :  tensor([0.6496, 0.3504])
# wrong_example :  tensor([0.3507, 0.6493])
# wrong_example :  tensor([0.3516, 0.6484])
# wrong_example :  tensor([0.6476, 0.3524])
# wrong_example :  tensor([0.6474, 0.3526])
# wrong_example :  tensor([0.6469, 0.3531])
# wrong_example :  tensor([0.3535, 0.6465])
# wrong_example :  tensor([0.3537, 0.6463])
# wrong_example :  tensor([0.3552, 0.6448])
# wrong_example :  tensor([0.6447, 0.3553])
# wrong_example :  tensor([0.6443, 0.3557])
# wrong_example :  tensor([0.6422, 0.3578])
# wrong_example :  tensor([0.6421, 0.3579])
# wrong_example :  tensor([0.3579, 0.6421])
# wrong_example :  tensor([0.3580, 0.6420])
# wrong_example :  tensor([0.6419, 0.3581])
# wrong_example :  tensor([0.6411, 0.3589])
# wrong_example :  tensor([0.6404, 0.3596])
# wrong_example :  tensor([0.6403, 0.3597])
# wrong_example :  tensor([0.6399, 0.3601])
# wrong_example :  tensor([0.3604, 0.6396])
# wrong_example :  tensor([0.3614, 0.6386])
# wrong_example :  tensor([0.6383, 0.3617])
# wrong_example :  tensor([0.6382, 0.3618])
# wrong_example :  tensor([0.6380, 0.3620])
# wrong_example :  tensor([0.3623, 0.6377])
# wrong_example :  tensor([0.6375, 0.3625])
# wrong_example :  tensor([0.3627, 0.6373])
# wrong_example :  tensor([0.6372, 0.3628])
# wrong_example :  tensor([0.3651, 0.6349])
# wrong_example :  tensor([0.3662, 0.6338])
# wrong_example :  tensor([0.6335, 0.3665])
# wrong_example :  tensor([0.6327, 0.3673])
# wrong_example :  tensor([0.3673, 0.6327])
# wrong_example :  tensor([0.3703, 0.6297])
# wrong_example :  tensor([0.6292, 0.3708])
# wrong_example :  tensor([0.6288, 0.3712])
# wrong_example :  tensor([0.3716, 0.6284])
# wrong_example :  tensor([0.3721, 0.6279])
# wrong_example :  tensor([0.3727, 0.6273])
# wrong_example :  tensor([0.6270, 0.3730])
# wrong_example :  tensor([0.3738, 0.6262])
# wrong_example :  tensor([0.6262, 0.3738])
# wrong_example :  tensor([0.6260, 0.3740])
# wrong_example :  tensor([0.3740, 0.6260])
# wrong_example :  tensor([0.3744, 0.6256])
# wrong_example :  tensor([0.6251, 0.3749])
# wrong_example :  tensor([0.6246, 0.3754])
# wrong_example :  tensor([0.3760, 0.6240])
# wrong_example :  tensor([0.6238, 0.3762])
# wrong_example :  tensor([0.3762, 0.6238])
# wrong_example :  tensor([0.6227, 0.3773])
# wrong_example :  tensor([0.6210, 0.3790])
# wrong_example :  tensor([0.3801, 0.6199])
# wrong_example :  tensor([0.3804, 0.6196])
# wrong_example :  tensor([0.6196, 0.3804])
# wrong_example :  tensor([0.6194, 0.3806])
# wrong_example :  tensor([0.3809, 0.6191])
# wrong_example :  tensor([0.3819, 0.6181])
# wrong_example :  tensor([0.3822, 0.6178])
# wrong_example :  tensor([0.6176, 0.3824])
# wrong_example :  tensor([0.6173, 0.3827])
# wrong_example :  tensor([0.6171, 0.3829])
# wrong_example :  tensor([0.6162, 0.3838])
# wrong_example :  tensor([0.3838, 0.6162])
# wrong_example :  tensor([0.3839, 0.6161])
# wrong_example :  tensor([0.6159, 0.3841])
# wrong_example :  tensor([0.6155, 0.3845])
# wrong_example :  tensor([0.3845, 0.6155])
# wrong_example :  tensor([0.3847, 0.6153])
# wrong_example :  tensor([0.6153, 0.3847])
# wrong_example :  tensor([0.3851, 0.6149])
# wrong_example :  tensor([0.3856, 0.6144])
# wrong_example :  tensor([0.3858, 0.6142])
# wrong_example :  tensor([0.6141, 0.3859])
# wrong_example :  tensor([0.6141, 0.3859])
# wrong_example :  tensor([0.3860, 0.6140])
# wrong_example :  tensor([0.6137, 0.3863])
# wrong_example :  tensor([0.3865, 0.6135])
# wrong_example :  tensor([0.3865, 0.6135])
# wrong_example :  tensor([0.3869, 0.6131])
# wrong_example :  tensor([0.6129, 0.3871])
# wrong_example :  tensor([0.3876, 0.6124])
# wrong_example :  tensor([0.6122, 0.3878])
# wrong_example :  tensor([0.6120, 0.3880])
# wrong_example :  tensor([0.3883, 0.6117])
# wrong_example :  tensor([0.3885, 0.6115])
# wrong_example :  tensor([0.3886, 0.6114])
# wrong_example :  tensor([0.3889, 0.6111])
# wrong_example :  tensor([0.6107, 0.3893])
# wrong_example :  tensor([0.3902, 0.6098])
# wrong_example :  tensor([0.6090, 0.3910])
# wrong_example :  tensor([0.3918, 0.6082])
# wrong_example :  tensor([0.6071, 0.3929])
# wrong_example :  tensor([0.6060, 0.3940])
# wrong_example :  tensor([0.6059, 0.3941])
# wrong_example :  tensor([0.3942, 0.6058])
# wrong_example :  tensor([0.6051, 0.3949])
# wrong_example :  tensor([0.6049, 0.3951])
# wrong_example :  tensor([0.6045, 0.3955])
# wrong_example :  tensor([0.6036, 0.3964])
# wrong_example :  tensor([0.6031, 0.3969])
# wrong_example :  tensor([0.6029, 0.3971])
# wrong_example :  tensor([0.3972, 0.6028])
# wrong_example :  tensor([0.6027, 0.3973])
# wrong_example :  tensor([0.3980, 0.6020])
# wrong_example :  tensor([0.3984, 0.6016])
# wrong_example :  tensor([0.3985, 0.6015])
# wrong_example :  tensor([0.3991, 0.6009])
# wrong_example :  tensor([0.6002, 0.3998])
# wrong_example :  tensor([0.5990, 0.4010])
# wrong_example :  tensor([0.5988, 0.4012])
# wrong_example :  tensor([0.5982, 0.4018])
# wrong_example :  tensor([0.5982, 0.4018])
# wrong_example :  tensor([0.4019, 0.5981])
# wrong_example :  tensor([0.5975, 0.4025])
# wrong_example :  tensor([0.5970, 0.4030])
# wrong_example :  tensor([0.5963, 0.4037])
# wrong_example :  tensor([0.5960, 0.4040])
# wrong_example :  tensor([0.4053, 0.5947])
# wrong_example :  tensor([0.4066, 0.5934])
# wrong_example :  tensor([0.4069, 0.5931])
# wrong_example :  tensor([0.5929, 0.4071])
# wrong_example :  tensor([0.5928, 0.4072])
# wrong_example :  tensor([0.4073, 0.5927])
# wrong_example :  tensor([0.4085, 0.5915])
# wrong_example :  tensor([0.5913, 0.4087])
# wrong_example :  tensor([0.5912, 0.4088])
# wrong_example :  tensor([0.4092, 0.5908])
# wrong_example :  tensor([0.4092, 0.5908])
# wrong_example :  tensor([0.4099, 0.5901])
# wrong_example :  tensor([0.5895, 0.4105])
# wrong_example :  tensor([0.5892, 0.4108])
# wrong_example :  tensor([0.5891, 0.4109])
# wrong_example :  tensor([0.5874, 0.4126])
# wrong_example :  tensor([0.5870, 0.4130])
# wrong_example :  tensor([0.5851, 0.4149])
# wrong_example :  tensor([0.4151, 0.5849])
# wrong_example :  tensor([0.5825, 0.4175])
# wrong_example :  tensor([0.5811, 0.4189])
# wrong_example :  tensor([0.5810, 0.4190])
# wrong_example :  tensor([0.5808, 0.4192])
# wrong_example :  tensor([0.5807, 0.4193])
# wrong_example :  tensor([0.4193, 0.5807])
# wrong_example :  tensor([0.4200, 0.5800])
# wrong_example :  tensor([0.4204, 0.5796])
# wrong_example :  tensor([0.5782, 0.4218])
# wrong_example :  tensor([0.4220, 0.5780])
# wrong_example :  tensor([0.4224, 0.5776])
# wrong_example :  tensor([0.4239, 0.5761])
# wrong_example :  tensor([0.5759, 0.4241])
# wrong_example :  tensor([0.4251, 0.5749])
# wrong_example :  tensor([0.4259, 0.5741])
# wrong_example :  tensor([0.5736, 0.4264])
# wrong_example :  tensor([0.5733, 0.4267])
# wrong_example :  tensor([0.4267, 0.5733])
# wrong_example :  tensor([0.4273, 0.5727])
# wrong_example :  tensor([0.4274, 0.5726])
# wrong_example :  tensor([0.5726, 0.4274])
# wrong_example :  tensor([0.5725, 0.4275])
# wrong_example :  tensor([0.4283, 0.5717])
# wrong_example :  tensor([0.4286, 0.5714])
# wrong_example :  tensor([0.4286, 0.5714])
# wrong_example :  tensor([0.4288, 0.5712])
# wrong_example :  tensor([0.5711, 0.4289])
# wrong_example :  tensor([0.5704, 0.4296])
# wrong_example :  tensor([0.5703, 0.4297])
# wrong_example :  tensor([0.4298, 0.5702])
# wrong_example :  tensor([0.5685, 0.4315])
# wrong_example :  tensor([0.4323, 0.5677])
# wrong_example :  tensor([0.4342, 0.5658])
# wrong_example :  tensor([0.5650, 0.4350])
# wrong_example :  tensor([0.5642, 0.4358])
# wrong_example :  tensor([0.5639, 0.4361])
# wrong_example :  tensor([0.5635, 0.4365])
# wrong_example :  tensor([0.5630, 0.4370])
# wrong_example :  tensor([0.5620, 0.4380])
# wrong_example :  tensor([0.5619, 0.4381])
# wrong_example :  tensor([0.4385, 0.5615])
# wrong_example :  tensor([0.5601, 0.4399])
# wrong_example :  tensor([0.5594, 0.4406])
# wrong_example :  tensor([0.5594, 0.4406])
# wrong_example :  tensor([0.5593, 0.4407])
# wrong_example :  tensor([0.4408, 0.5592])
# wrong_example :  tensor([0.4432, 0.5568])
# wrong_example :  tensor([0.5558, 0.4442])
# wrong_example :  tensor([0.5544, 0.4456])
# wrong_example :  tensor([0.5530, 0.4470])
# wrong_example :  tensor([0.5518, 0.4482])
# wrong_example :  tensor([0.5508, 0.4492])
# wrong_example :  tensor([0.5507, 0.4493])
# wrong_example :  tensor([0.5507, 0.4493])
# wrong_example :  tensor([0.4494, 0.5506])
# wrong_example :  tensor([0.4495, 0.5505])
# wrong_example :  tensor([0.5501, 0.4499])
# wrong_example :  tensor([0.4503, 0.5497])
# wrong_example :  tensor([0.5485, 0.4515])
# wrong_example :  tensor([0.4515, 0.5485])
# wrong_example :  tensor([0.5480, 0.4520])
# wrong_example :  tensor([0.5476, 0.4524])
# wrong_example :  tensor([0.5470, 0.4530])
# wrong_example :  tensor([0.4555, 0.5445])
# wrong_example :  tensor([0.5441, 0.4559])
# wrong_example :  tensor([0.4571, 0.5429])
# wrong_example :  tensor([0.4573, 0.5427])
# wrong_example :  tensor([0.5421, 0.4579])
# wrong_example :  tensor([0.4579, 0.5421])
# wrong_example :  tensor([0.4588, 0.5412])
# wrong_example :  tensor([0.5403, 0.4597])
# wrong_example :  tensor([0.4598, 0.5402])
# wrong_example :  tensor([0.5401, 0.4599])
# wrong_example :  tensor([0.5395, 0.4605])
# wrong_example :  tensor([0.5393, 0.4607])
# wrong_example :  tensor([0.5378, 0.4622])
# wrong_example :  tensor([0.5374, 0.4626])
# wrong_example :  tensor([0.4629, 0.5371])
# wrong_example :  tensor([0.5367, 0.4633])
# wrong_example :  tensor([0.4635, 0.5365])
# wrong_example :  tensor([0.5354, 0.4646])
# wrong_example :  tensor([0.4652, 0.5348])
# wrong_example :  tensor([0.5344, 0.4656])
# wrong_example :  tensor([0.4661, 0.5339])
# wrong_example :  tensor([0.5338, 0.4662])
# wrong_example :  tensor([0.4666, 0.5334])
# wrong_example :  tensor([0.5331, 0.4669])
# wrong_example :  tensor([0.5327, 0.4673])
# wrong_example :  tensor([0.5318, 0.4682])
# wrong_example :  tensor([0.5317, 0.4683])
# wrong_example :  tensor([0.4686, 0.5314])
# wrong_example :  tensor([0.4687, 0.5313])
# wrong_example :  tensor([0.4689, 0.5311])
# wrong_example :  tensor([0.4690, 0.5310])
# wrong_example :  tensor([0.5310, 0.4690])
# wrong_example :  tensor([0.5301, 0.4699])
# wrong_example :  tensor([0.5299, 0.4701])
# wrong_example :  tensor([0.4704, 0.5296])
# wrong_example :  tensor([0.5276, 0.4724])
# wrong_example :  tensor([0.4729, 0.5271])
# wrong_example :  tensor([0.5269, 0.4731])
# wrong_example :  tensor([0.4732, 0.5268])
# wrong_example :  tensor([0.5266, 0.4734])
# wrong_example :  tensor([0.5264, 0.4736])
# wrong_example :  tensor([0.4739, 0.5261])
# wrong_example :  tensor([0.5249, 0.4751])
# wrong_example :  tensor([0.5226, 0.4774])
# wrong_example :  tensor([0.5224, 0.4776])
# wrong_example :  tensor([0.4788, 0.5212])
# wrong_example :  tensor([0.5206, 0.4794])
# wrong_example :  tensor([0.4795, 0.5205])
# wrong_example :  tensor([0.4799, 0.5201])
# wrong_example :  tensor([0.5200, 0.4800])
# wrong_example :  tensor([0.5191, 0.4809])
# wrong_example :  tensor([0.4811, 0.5189])
# wrong_example :  tensor([0.4814, 0.5186])
# wrong_example :  tensor([0.5181, 0.4819])
# wrong_example :  tensor([0.5181, 0.4819])
# wrong_example :  tensor([0.4819, 0.5181])
# wrong_example :  tensor([0.4825, 0.5175])
# wrong_example :  tensor([0.4833, 0.5167])
# wrong_example :  tensor([0.5166, 0.4834])
# wrong_example :  tensor([0.4837, 0.5163])
# wrong_example :  tensor([0.4840, 0.5160])
# wrong_example :  tensor([0.5160, 0.4840])
# wrong_example :  tensor([0.4849, 0.5151])
# wrong_example :  tensor([0.5151, 0.4849])
# wrong_example :  tensor([0.4852, 0.5148])
# wrong_example :  tensor([0.4852, 0.5148])
# wrong_example :  tensor([0.5136, 0.4864])
# wrong_example :  tensor([0.5128, 0.4872])
# wrong_example :  tensor([0.5116, 0.4884])
# wrong_example :  tensor([0.5113, 0.4887])
# wrong_example :  tensor([0.4888, 0.5112])
# wrong_example :  tensor([0.5106, 0.4894])
# wrong_example :  tensor([0.4895, 0.5105])
# wrong_example :  tensor([0.5103, 0.4897])
# wrong_example :  tensor([0.5102, 0.4898])
# wrong_example :  tensor([0.4902, 0.5098])
# wrong_example :  tensor([0.5098, 0.4902])
# wrong_example :  tensor([0.4903, 0.5097])
# wrong_example :  tensor([0.5096, 0.4904])
# wrong_example :  tensor([0.5089, 0.4911])
# wrong_example :  tensor([0.4912, 0.5088])
# wrong_example :  tensor([0.5083, 0.4917])
# wrong_example :  tensor([0.5078, 0.4922])
# wrong_example :  tensor([0.5074, 0.4926])
# wrong_example :  tensor([0.4927, 0.5073])
# wrong_example :  tensor([0.4933, 0.5067])
# wrong_example :  tensor([0.4936, 0.5064])
# wrong_example :  tensor([0.4941, 0.5059])
# wrong_example :  tensor([0.5059, 0.4941])
# wrong_example :  tensor([0.5050, 0.4950])
# wrong_example :  tensor([0.4950, 0.5050])
# wrong_example :  tensor([0.5045, 0.4955])
# wrong_example :  tensor([0.5044, 0.4956])
# wrong_example :  tensor([0.4959, 0.5041])
# wrong_example :  tensor([0.4971, 0.5029])
# wrong_example :  tensor([0.4972, 0.5028])
# wrong_example :  tensor([0.4972, 0.5028])
# wrong_example :  tensor([0.5024, 0.4976])
# wrong_example :  tensor([0.4978, 0.5022])
# wrong_example :  tensor([0.5018, 0.4982])
# wrong_example :  tensor([0.5016, 0.4984])
# wrong_example :  tensor([0.5012, 0.4988])
# wrong_example :  tensor([0.4989, 0.5011])
# wrong_example :  tensor([0.5008, 0.4992])
# wrong_example :  tensor([0.4997, 0.5003])
# wrong_example :  tensor([0.4997, 0.5003])

# %%
classes = test_dataset.classes
n_images = 5
plot_most_correct_wrong(correct_examples, wrong_examples, classes, n_images)
